# %% [markdown]
# ### Import the libraries

# %%
import camelot as cam

# %% [markdown]
# ### upload the pdf file

# %%
tables = cam.read_pdf("makkah.pdf",pages="1",flavor='stream')
tables
# Out:
# <TableList n=1>

# %% [markdown]
# ### Find the table in pdf

# %%
tables[0].df
# Out:
#                0                                                  1  \
# 0   05 Sept 2022
# 1
# 2
# 3                                                             Hotel
# 4
# 5                                                       Emaar Grand
# 6
# 7                                     Breakfast\n \n \nLunch/ Diner
# 8                                                     20 SR \n40 SR
# 9
# 10                                                            Hotel
# 11
# 12                                                   Emaar Al Manar
# 13                                                  Emaar Andalusia
# 14                                                  Emaar Al Khalil
# 15                                                      Emaar Elite
# 16
# 17                                            (Shuttle Bus Service)
# 18                                                  Meals\n \nRates
# 19                                    Breakfast\n \n \nLunch/ Diner
# ...

# %% [markdown]
# ### How to find the specific column in the pdf

# %%
tables[0].df[[2,3]]
# Out:
#                                    2                      3
# 0
# 1   From 05 Sept - Till 30 Sept 2022
# 2                                                     Rooms
# 3
# 4                             Double                 Triple
# 5                                                    145 SR
# 6   Meals Rates per person per night
# 7                         H.B Turkey  H.B Iraq\n \nF.B Iraq
# 8                              50 SR          45 SR \n60 SR
# 9                                                     Rooms
# 10
# 11                            Double                 Triple
# 12                                                   110 SR
# 13                                                   145 SR
# 14                                                   110 SR
# 15
# 16                                                   100 SR
# 17
# 18              per person per night      (For groups only)
# 19                        H.B Turkey  H.B Iraq\n \nF.B Iraq
# ...
